# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("C:\\Users\\user\\Desktop\\datas\\ticket_08_2017.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data
# Out:
#         sync_ticket_id  sync_tkt_owner_id  sync_tkt_device_id  \
# 0               402854           15050034                  34
# 1               402855           15050034                  34
# 2               402856           15050034                  34
# 3               402894           15050034                  34
# 4               402966           15050034                  34
# ...                ...                ...                 ...
# 217383          641842           15050217                 234
# 217384          641843           15050217                 234
# 217385          641844           15050217                 234
# 217386          641845           15050217                 234
# 217387          641846           15050217                 234
#
#        sync_tkt_employee_id sync_tkt_vehicle_id sync_tkt_route_code  \
# 0                      EMP1        KL-06-D-9858                9858
# 1                      EMP1        KL-06-D-9858                9858
# ...

# %%
data.head()
# Out:
#    sync_ticket_id  sync_tkt_owner_id  sync_tkt_device_id sync_tkt_employee_id  \
# 0          402854           15050034                  34                 EMP1
# 1          402855           15050034                  34                 EMP1
# 2          402856           15050034                  34                 EMP1
# 3          402894           15050034                  34                 EMP1
# 4          402966           15050034                  34                 EMP1
#
#   sync_tkt_vehicle_id sync_tkt_route_code sync_tkt_route_name  \
# 0        KL-06-D-9858                9858        CHRY-NEDKNDM
# 1        KL-06-D-9858                9858        CHRY-NEDKNDM
# 2        KL-06-D-9858                9858        CHRY-NEDKNDM
# 3        KL-06-D-9858                9858        CHRY-NEDKNDM
# 4        KL-06-D-9858                9858        CHRY-NEDKNDM
#
#    sync_tkt_schedule_no  sync_tkt_trip_no sync_tkt_start_stage_name  ...  \
# ...

# %%
data.tail()
# Out:
#         sync_ticket_id  sync_tkt_owner_id  sync_tkt_device_id  \
# 217383          641842           15050217                 234
# 217384          641843           15050217                 234
# 217385          641844           15050217                 234
# 217386          641845           15050217                 234
# 217387          641846           15050217                 234
#
#        sync_tkt_employee_id sync_tkt_vehicle_id sync_tkt_route_code  \
# 217383                 EMP1        KL-35-F-7257                  56
# 217384                 EMP1        KL-35-F-7257                  56
# 217385                 EMP1        KL-35-F-7257                  56
# 217386                 EMP1        KL-35-F-7257                  56
# 217387                 EMP1        KL-35-F-7257                  56
#
#        sync_tkt_route_name  sync_tkt_schedule_no  sync_tkt_trip_no  \
# 217383         KTYM-CHRTLA                     1                 2
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of         sync_ticket_id  sync_tkt_owner_id  sync_tkt_device_id  \
# 0               402854           15050034                  34
# 1               402855           15050034                  34
# 2               402856           15050034                  34
# 3               402894           15050034                  34
# 4               402966           15050034                  34
# ...                ...                ...                 ...
# 217383          641842           15050217                 234
# 217384          641843           15050217                 234
# 217385          641844           15050217                 234
# 217386          641845           15050217                 234
# 217387          641846           15050217                 234
#
#        sync_tkt_employee_id sync_tkt_vehicle_id sync_tkt_route_code  \
# 0                      EMP1        KL-06-D-9858                9858
# ...

# %%
print(data)
# Out:
#         sync_ticket_id  sync_tkt_owner_id  sync_tkt_device_id  \
# 0               402854           15050034                  34
# 1               402855           15050034                  34
# 2               402856           15050034                  34
# 3               402894           15050034                  34
# 4               402966           15050034                  34
# ...                ...                ...                 ...
# 217383          641842           15050217                 234
# 217384          641843           15050217                 234
# 217385          641844           15050217                 234
# 217386          641845           15050217                 234
# 217387          641846           15050217                 234
#
#        sync_tkt_employee_id sync_tkt_vehicle_id sync_tkt_route_code  \
# 0                      EMP1        KL-06-D-9858                9858
# 1                      EMP1        KL-06-D-9858                9858
# ...

# %%
print(data.columns)
# Out:
# Index(['sync_ticket_id', 'sync_tkt_owner_id', 'sync_tkt_device_id',
#        'sync_tkt_employee_id', 'sync_tkt_vehicle_id', 'sync_tkt_route_code',
#        'sync_tkt_route_name', 'sync_tkt_schedule_no', 'sync_tkt_trip_no',
#        'sync_tkt_start_stage_name', 'sync_tkt_end_stage_name', 'sync_tkt_uid',
#        'sync_tkt_full_count', 'sync_tkt_half_count', 'sync_tkt_student_count',
#        'sync_tkt_ph_count', 'sync_tkt_pass_count', 'sync_tkt_luggage_count',
#        'sync_tkt_warrant_count', 'sync_tkt_full_amount',
#        'sync_tkt_half_amount', 'sync_tkt_student_amount', 'sync_tkt_ph_amount',
#        'sync_tkt_pass_amount', 'sync_tkt_luggage_amount',
#        'sync_tkt_warrant_amount', 'sync_tkt_updown_trip', 'sync_tkt_ticket_no',
#        'sync_tkt_total_amount', 'sync_tkt_discount_amount',
#        'sync_tkt_card_ticket_status', 'sync_tkt_card_id',
#        'sync_tkt_card_balance_amount', 'sync_tkt_card_prv_balance_amount',
# ...

# %%
df1=data.iloc[:,6:13]
print(df1.columns)
# Out:
# Index(['sync_tkt_route_name', 'sync_tkt_schedule_no', 'sync_tkt_trip_no',
#        'sync_tkt_start_stage_name', 'sync_tkt_end_stage_name', 'sync_tkt_uid',
#        'sync_tkt_full_count'],
#       dtype='object')

# %%
print(df1['sync_tkt_route_name'])
# Out:
# 0         CHRY-NEDKNDM
# 1         CHRY-NEDKNDM
# 2         CHRY-NEDKNDM
# 3         CHRY-NEDKNDM
# 4         CHRY-NEDKNDM
#               ...
# 217383     KTYM-CHRTLA
# 217384     KTYM-CHRTLA
# 217385     KTYM-CHRTLA
# 217386     KTYM-CHRTLA
# 217387     KTYM-CHRTLA
# Name: sync_tkt_route_name, Length: 217388, dtype: object

# %%
print(df1['sync_tkt_schedule_no'])
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 217383    1
# 217384    1
# 217385    1
# 217386    1
# 217387    1
# Name: sync_tkt_schedule_no, Length: 217388, dtype: int64

# %%
print(df1['sync_tkt_trip_no'])
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 217383    2
# 217384    2
# 217385    2
# 217386    2
# 217387    2
# Name: sync_tkt_trip_no, Length: 217388, dtype: int64

# %%
print(df1[ 'sync_tkt_start_stage_name'])
# Out:
# 0          KATTAPANA
# 1          KATTAPANA
# 2          KATTAPANA
# 3             SWARAJ
# 4         MATTUKATTA
#              ...
# 217383      CHERTALA
# 217384      CHERTALA
# 217385      CHERTALA
# 217386      CHERTALA
# 217387      CHERTALA
# Name: sync_tkt_start_stage_name, Length: 217388, dtype: object

# %%
print(df1[ 'sync_tkt_end_stage_name'])
# Out:
# 0           MARUKULAM
# 1              PARAPU
# 2         KUTTIKANNAM
# 3         KUTTIKANNAM
# 4         KUTTIKANNAM
#              ...
# 217383      AALUMOODU
# 217384       KOTTAYAM
# 217385       ILLICKAL
# 217386       KOTTAYAM
# 217387      KATACHIRA
# Name: sync_tkt_end_stage_name, Length: 217388, dtype: object

# %%
print(df1['sync_tkt_uid'])
# Out:
# 0         2017-07-31 14:43:35
# 1         2017-07-31 14:43:35
# 2         2017-07-31 14:43:35
# 3         2017-07-31 14:43:35
# 4         2017-07-31 14:43:35
#                  ...
# 217383    2017-08-31 14:00:06
# 217384    2017-08-31 14:00:06
# 217385    2017-08-31 14:00:06
# 217386    2017-08-31 14:00:06
# 217387    2017-08-31 14:00:06
# Name: sync_tkt_uid, Length: 217388, dtype: object

# %%
print(df1['sync_tkt_full_count'])
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 217383    1
# 217384    1
# 217385    1
# 217386    1
# 217387    1
# Name: sync_tkt_full_count, Length: 217388, dtype: int64

# %%
df2=df1[['sync_tkt_route_name', 'sync_tkt_schedule_no', 'sync_tkt_trip_no',
       'sync_tkt_start_stage_name', 'sync_tkt_end_stage_name','sync_tkt_full_count']]
print(df2)
# Out:
#        sync_tkt_route_name  sync_tkt_schedule_no  sync_tkt_trip_no  \
# 0             CHRY-NEDKNDM                     1                 2
# 1             CHRY-NEDKNDM                     1                 2
# 2             CHRY-NEDKNDM                     1                 2
# 3             CHRY-NEDKNDM                     1                 2
# 4             CHRY-NEDKNDM                     1                 2
# ...                    ...                   ...               ...
# 217383         KTYM-CHRTLA                     1                 2
# 217384         KTYM-CHRTLA                     1                 2
# 217385         KTYM-CHRTLA                     1                 2
# 217386         KTYM-CHRTLA                     1                 2
# 217387         KTYM-CHRTLA                     1                 2
#
#        sync_tkt_start_stage_name sync_tkt_end_stage_name  sync_tkt_full_count
# 0                      KATTAPANA               MARUKULAM                    1
# ...

# %%
df2
# Out:
#        sync_tkt_route_name  sync_tkt_schedule_no  sync_tkt_trip_no  \
# 0             CHRY-NEDKNDM                     1                 2
# 1             CHRY-NEDKNDM                     1                 2
# 2             CHRY-NEDKNDM                     1                 2
# 3             CHRY-NEDKNDM                     1                 2
# 4             CHRY-NEDKNDM                     1                 2
# ...                    ...                   ...               ...
# 217383         KTYM-CHRTLA                     1                 2
# 217384         KTYM-CHRTLA                     1                 2
# 217385         KTYM-CHRTLA                     1                 2
# 217386         KTYM-CHRTLA                     1                 2
# 217387         KTYM-CHRTLA                     1                 2
#
#        sync_tkt_start_stage_name sync_tkt_end_stage_name  sync_tkt_full_count
# 0                      KATTAPANA               MARUKULAM                    1
# ...

# %%
df3=df2.groupby(['sync_tkt_route_name','sync_tkt_schedule_no','sync_tkt_trip_no','sync_tkt_start_stage_name', 'sync_tkt_end_stage_name'],as_index=False).agg({ 'sync_tkt_full_count':'sum'})
df3
# Out:
#       sync_tkt_route_name  sync_tkt_schedule_no  sync_tkt_trip_no  \
# 0            ANGLVLY-KTYM                     1                 1
# 1            ANGLVLY-KTYM                     1                 1
# 2            ANGLVLY-KTYM                     1                 1
# 3            ANGLVLY-KTYM                     1                 1
# 4            ANGLVLY-KTYM                     1                 1
# ...                   ...                   ...               ...
# 45745      VAIKOM-PNCHKAD                     3                 5
# 45746      VAIKOM-PNCHKAD                     3                 6
# 45747      VAIKOM-PNCHKAD                     3                 6
# 45748      VAIKOM-PNCHKAD                     3                 7
# 45749      VAIKOM-PNCHKAD                     3                 7
#
#       sync_tkt_start_stage_name sync_tkt_end_stage_name  sync_tkt_full_count
# 0                         8MILE                MANIMALA                   13
# ...

# %%
df3.head()
# Out:
#   sync_tkt_route_name  sync_tkt_schedule_no  sync_tkt_trip_no  \
# 0        ANGLVLY-KTYM                     1                 1
# 1        ANGLVLY-KTYM                     1                 1
# 2        ANGLVLY-KTYM                     1                 1
# 3        ANGLVLY-KTYM                     1                 1
# 4        ANGLVLY-KTYM                     1                 1
#
#   sync_tkt_start_stage_name sync_tkt_end_stage_name  sync_tkt_full_count
# 0                     8MILE                MANIMALA                   13
# 1                     8MILE                  PKALAM                    3
# 2                 ALAMPALLY                   KPARA                    1
# 3                 ALAMPALLY                MANIMALA                    1
# 4                  CHETTEDA                MANIMALA                    3

# %%
df3.tail()
# Out:
#       sync_tkt_route_name  sync_tkt_schedule_no  sync_tkt_trip_no  \
# 45745      VAIKOM-PNCHKAD                     3                 5
# 45746      VAIKOM-PNCHKAD                     3                 6
# 45747      VAIKOM-PNCHKAD                     3                 6
# 45748      VAIKOM-PNCHKAD                     3                 7
# 45749      VAIKOM-PNCHKAD                     3                 7
#
#       sync_tkt_start_stage_name sync_tkt_end_stage_name  sync_tkt_full_count
# 45745                    VAIKOM              PUTANPALOM                    1
# 45746                 KUMARAKOM                KOTTAYAM                    1
# 45747                    VAIKOM              TALAYAZHOM                    1
# 45748                    VAIKOM             KAVANATNKAR                    1
# 45749                    VAIKOM                KOTTAYAM                    1

# %% [markdown]
# Look for is there any NAN values

# %%
df3.isnull().sum()
# Out:
# sync_tkt_route_name          0
# sync_tkt_schedule_no         0
# sync_tkt_trip_no             0
# sync_tkt_start_stage_name    0
# sync_tkt_end_stage_name      0
# sync_tkt_full_count          0
# dtype: int64

# %% [markdown]
#  Take sync_tkt_full_count as Y

# %%
Y=df3.iloc[:,[-1]].values #values is to be used, otherwise we get as dataframe
print(Y)
# Out:
# [[13]
#  [ 3]
#  [ 1]
#  ...
#  [ 1]
#  [ 1]
#  [ 1]]

# %% [markdown]
#  Take sync_tkt_route_name,sync_tkt_schedule_no,sync_tkt_trip_no,sync_tkt_start_stage_name,sync_tkt_end_stage_name as X

# %%
X=df3.iloc[:,[0,1,2,3,4]].values
print(X)
# Out:
# [['ANGLVLY-KTYM' 1 1 '8MILE' 'MANIMALA']
#  ['ANGLVLY-KTYM' 1 1 '8MILE' 'PKALAM']
#  ['ANGLVLY-KTYM' 1 1 'ALAMPALLY' 'KPARA']
#  ...
#  ['VAIKOM-PNCHKAD' 3 6 'VAIKOM' 'TALAYAZHOM']
#  ['VAIKOM-PNCHKAD' 3 7 'VAIKOM' 'KAVANATNKAR']
#  ['VAIKOM-PNCHKAD' 3 7 'VAIKOM' 'KOTTAYAM']]

# %% [markdown]
#  We want to Label encode sync_tkt_route_name,sync_tkt_start_stage_name,sync_tkt_end_stage_name

# %%
labelncoder=LabelEncoder()
X[:,0]=labelncoder.fit_transform(X[:,0])
X[:,3]=labelncoder.fit_transform(X[:,3])
X[:,4]=labelncoder.fit_transform(X[:,4])
print(X)
# Out:
# [[0 1 1 54 736]
#  [0 1 1 54 1067]
#  [0 1 1 71 582]
#  ...
#  [129 3 6 1300 1191]
#  [129 3 7 1300 454]
#  [129 3 7 1300 570]]

# %% [markdown]
#  By using Linear Regression

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
y_pred=regressor.predict(X_test)
print('predictions: ',y_pred)
# Out:
# predictions:  [[4.12277105]
#  [5.64553425]
#  [5.33217828]
#  ...
#  [6.33836493]
#  [2.75635776]
#  [6.18445166]]

# %% [markdown]
#  These are the predicted values of Linear Regression.

# %%
print(y_pred)
# Out:
# [[4.12277105]
#  [5.64553425]
#  [5.33217828]
#  ...
#  [6.33836493]
#  [2.75635776]
#  [6.18445166]]

# %%
from sklearn.metrics import  r2_score
rl=r2_score(Y_test,y_pred)
print(rl)
# Out:
# 0.01668427598499711

# %% [markdown]
#  By using Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=100,random_state=40)
model.fit(X_train,Y_train)
# Out:
# <ipython-input-26-6de1f1032901>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train,Y_train)
# RandomForestRegressor(random_state=40)

# %%
prediction_Random_Forest=model.predict(X_test)

# %% [markdown]
# Predicted values by using Random Forest Regression

# %%
print(prediction_Random_Forest)
# Out:
# [ 1.48  4.95 13.62 ...  7.06  2.61  3.26]

# %%
from sklearn.metrics import  r2_score
import numpy as np
r2 = r2_score(Y_test,prediction_Random_Forest)
print(r2)
# Out:
# 0.1127310036185446

# %% [markdown]
#  By using Elastic Net

# %%
from sklearn.linear_model import ElasticNet
ela_reg=ElasticNet()
ela_reg.fit(X_train,Y_train)
# Out:
# ElasticNet()

# %%
ela_reg.fit(X_train,Y_train)
# Out:
# ElasticNet()

# %%
ela_predict=ela_reg.predict(X_test)

# %% [markdown]
# Predicted Values by using Elastic Net Regression

# %%
print(ela_predict)
# Out:
# [4.76127009 5.43818543 4.95485271 ... 5.81825725 4.01853775 5.71123939]

# %%
ela_score=r2_score(Y_test,ela_predict)
print(ela_score)
# Out:
# 0.010592068929336285

# %% [markdown]
# By using Bagging Regression

# %%
from sklearn.ensemble import BaggingRegressor
bagging_regressor=BaggingRegressor()
bagging_regressor.fit(X_train,Y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# BaggingRegressor()

# %%
bagging_predictions=bagging_regressor.predict(X_test)

# %% [markdown]
# These are the predicted values by using Bagging Regression

# %%
print(bagging_predictions)
# Out:
# [ 1.6  4.5 17.2 ...  7.6  2.2  1.4]

# %%
Bagging_score=r2_score(Y_test,bagging_predictions)
print(Bagging_score)
# Out:
# 0.05011479935170726

# %%
bagging_predictions
# Out:
# array([ 1.6,  4.5, 17.2, ...,  7.6,  2.2,  1.4])

# %% [markdown]
# We want to convert Y_test and Y_pred to 1D array for making DataFrame

# %%
import numpy as np
Y_test_1D_array=Y_test.flatten()

# %%
y_pred_1D_array=y_pred.flatten()

# %%
Y_true=Y_test_1D_array
Predicted_data={'True Sales of Ticket in diffrent Root' : Y_true,
         'Predicted Sales of Ticket in diffrent Root_ Linear Regression ': y_pred_1D_array,
         'Predicted Sales of Ticket in diffrent Root_ Random Forest Regression ': prediction_Random_Forest,
         'Predicted Sales of Ticket in diffrent Root_ Elastic Net Regression ': ela_predict,
         'Predicted Sales of Ticket in diffrent Root_Bagging Regression ': bagging_predictions,}
Predicted_data=pd.DataFrame(Predicted_data)
Predicted_data
# Out:
#        True Sales of Ticket in diffrent Root  \
# 0                                          2
# 1                                          5
# 2                                          6
# 3                                          3
# 4                                          1
# ...                                      ...
# 13720                                      1
# 13721                                      1
# 13722                                      3
# 13723                                      1
# 13724                                      6
#
#        Predicted Sales of Ticket in diffrent Root_ Linear Regression   \
# 0                                               4.122771
# 1                                               5.645534
# 2                                               5.332178
# 3                                               5.091129
# 4                                               6.371768
# ...                                                  ...
# ...

# %%
Predicted_data.head()
# Out:
#    True Sales of Ticket in diffrent Root  \
# 0                                      2
# 1                                      5
# 2                                      6
# 3                                      3
# 4                                      1
#
#    Predicted Sales of Ticket in diffrent Root_ Linear Regression   \
# 0                                           4.122771
# 1                                           5.645534
# 2                                           5.332178
# 3                                           5.091129
# 4                                           6.371768
#
#    Predicted Sales of Ticket in diffrent Root_ Random Forest Regression   \
# 0                                               1.48
# 1                                               4.95
# 2                                              13.62
# 3                                               8.13
# 4                                               2.14
#
# ...

# %%
Predicted_data.tail()
# Out:
#        True Sales of Ticket in diffrent Root  \
# 13720                                      1
# 13721                                      1
# 13722                                      3
# 13723                                      1
# 13724                                      6
#
#        Predicted Sales of Ticket in diffrent Root_ Linear Regression   \
# 13720                                           6.475410
# 13721                                           6.314361
# 13722                                           6.338365
# 13723                                           2.756358
# 13724                                           6.184452
#
#        Predicted Sales of Ticket in diffrent Root_ Random Forest Regression   \
# 13720                                               6.70
# 13721                                               3.23
# 13722                                               7.06
# 13723                                               2.61
# ...

# %%
Predicted_data[0:60]
# Out:
#     True Sales of Ticket in diffrent Root  \
# 0                                       2
# 1                                       5
# 2                                       6
# 3                                       3
# 4                                       1
# 5                                       2
# 6                                       3
# 7                                       1
# 8                                       1
# 9                                      12
# 10                                      1
# 11                                      1
# 12                                      3
# 13                                      1
# 14                                      1
# 15                                      4
# 16                                      3
# 17                                      1
# 18                                      3
# 19                                      7
# 20                                      1
# ...
